# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaa-04/first_repo/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**

# %% [markdown]
# **Project Type**- Exploratory Data Analysis (Hotel Management)
#
# **Contribution**- Individual
#
# **Name**- Sana Mansoori

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# Hotel industry is a very volatile industry and the bookings depend on variety of factors such as type of hotels, seasonality, days of week ,ratings, avilability of room ,parking spaceand many more. This makes analyzing the patterns available in the past data more important to help the hotels plan better. Using the historical data, hotels can perform various campaigns to boost the business. We can use the past data to predict the future bookings.
#
# We will be using the data available to analyze the factors affecting the hotel bookings. These factors can be used for reporting the trends and predict the future bookings.
#
# We will be tackling this problem statement in three stages:
#
# 1.We will be analyzing some key metrics for hotel bookings like:
#
# The number of cancellations
#
# Number of bookings on weekday vs weekends
#
# Most preferred meal types
#
# Country wise bookings
#
# New customers acquired
#
# Customer lifetime value of the existing customers
#
# Type of rooms preferred by customers
#
# Booking types
#
# Hotels available for booking
#
# The revenue of the hotels
#
# 2.We will be using various lenses to look through the data to analyze patterns associated with each segment such as:
#
# The type of hotel
#
# Day of week
#
# Type of customers
#
# Type of rooms
#
# 3.Finally, we will also try to predict the future bookings either based on time series analysis or decision trees.
#
# Using the results from the above analysis, business can make key decisions regarding the customer experience they desire to deliver.

# %% [markdown]
# # **GitHub Link**

# %% [markdown]
# # **Data Description**

# %% [markdown]
# It contains the following features.
#
# hotel: Name of hotel ( City or Resort)
#
# is_canceled: Whether the booking is canceled or not (0 for no canceled and 1 for canceled)
#
# lead_time: time (in days) between booking transaction and actual arrival.
#
# arrival_date_year: Year of arrival
#
# arrival_date_month: month of arrival
#
# arrival_date_week_number: week number of arrival date.
#
# arrival_date_day_of_month: Day of month of arrival date
#
# stays_in_weekend_nights: No. of weekend nights spent in a hotel
#
# stays_in_week_nights: No. of weeknights spent in a hotel
#
# adults: No. of adults in single booking record.
#
# children: No. of children in single booking record.
#
# babies: No. of babies in single booking record.
#
# meal: Type of meal chosen
# country: Country of origin of customers (as mentioned by them)
#
# market_segment: What segment via booking was made and for what purpose.
#
# distribution_channel: Via which medium booking was made.
#
# is_repeated_guest: Whether the customer has made any booking before(0 for No and 1 for Yes)
#
# previous_cancellations: No. of previous canceled bookings.
#
# previous_bookings_not_canceled: No. of previous non-canceled bookings.
#
# reserved_room_type: Room type reserved by a customer.
#
# assigned_room_type: Room type assigned to the customer.
#
# booking_changes: No. of booking changes done by customers
#
# deposit_type: Type of deposit at the time of making a booking (No deposit/ Refundable/ No refund)
#
# agent: Id of agent for booking
# company: Id of the company making a booking
#
# days_in_waiting_list: No. of days on waiting list.
#
# customer_type: Type of customer(Transient, Group, etc.)
#
# adr: Average Daily rate.
#
# required_car_parking_spaces: No. of car parking asked in booking
#
# total_of_special_requests: total no. of special request.
#
# reservation_status: Whether a customer has checked out or canceled,or not showed
#
# reservation_status_date: Date of making reservation status.

# %% [markdown]
# # **Let's Begin!**

# %% [markdown]
# ## **1.Know Your Data**

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
filepath = '/content/drive/MyDrive/Hotel Bookings.csv'

# %%
df = pd.read_csv(filepath)

# %% [markdown]
# ### Dataset First View

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ## **2. Understanding Your Variables**

# %% [markdown]
# ### Dataset Columns

# %%
list(df.columns)
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %% [markdown]
# ### Variables Description

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## **3. Data Wrangling**

# %% [markdown]
# ### Data Cleaning

# %%
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
df['company'] = df['company'].fillna('unknown')
df['agent'] = df['agent'].fillna('unknown')

# %%
new_df = df.dropna()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118898 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
new_df.duplicated().value_counts()
# Out:
# False    86940
# True     31958
# dtype: int64

# %%
new_df.drop_duplicates(inplace = True)
# Out:
# <ipython-input-10-a18cfc528d69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop_duplicates(inplace = True)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86940 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86940 non-null  object
#  1   is_canceled                     86940 non-null  int64
#  2   lead_time                       86940 non-null  int64
#  3   arrival_date_year               86940 non-null  int64
#  4   arrival_date_month              86940 non-null  object
#  5   arrival_date_week_number        86940 non-null  int64
#  6   arrival_date_day_of_month       86940 non-null  int64
#  7   stays_in_weekend_nights         86940 non-null  int64
#  8   stays_in_week_nights            86940 non-null  int64
#  9   adults                          86940 non-null  int64
#  10  children                        86940 non-null  float64
#  11  babies                          86940 non-null  int64
# ...

# %%
new_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# **Conclusion:** After Data Cleaning, we have an updated dataset(new_df) which has 86940 rows and 32 columns.

# %% [markdown]
# ### Data Manipulation

# %%
new_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 3                    July                        27
# 4                    July                        27
# ...

# %%
new_df['num_of_bookings'] = 1
# Out:
# <ipython-input-13-65b172419f66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['num_of_bookings'] = 1

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86940 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86940 non-null  object
#  1   is_canceled                     86940 non-null  int64
#  2   lead_time                       86940 non-null  int64
#  3   arrival_date_year               86940 non-null  int64
#  4   arrival_date_month              86940 non-null  object
#  5   arrival_date_week_number        86940 non-null  int64
#  6   arrival_date_day_of_month       86940 non-null  int64
#  7   stays_in_weekend_nights         86940 non-null  int64
#  8   stays_in_week_nights            86940 non-null  int64
#  9   adults                          86940 non-null  int64
#  10  children                        86940 non-null  float64
#  11  babies                          86940 non-null  int64
# ...

# %% [markdown]
# # **4. Data Visualisation**

# %% [markdown]
# ## Most Preferred Hotel

# %%
new_df['hotel'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Pie Chart for Most Preferred Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preferred Hotel')

# %% [markdown]
# **Conclusion:** City Hotel is the most preferred hotel type by the guests. We can say City Hotel is the busiest hotel.

# %% [markdown]
# ## Cancelled or not cancelled booking

# %%
new_df['is_canceled'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Cancellation and non cancellation')
# Out:
# Text(0.5, 1.0, 'Cancellation and non cancellation')

# %% [markdown]
# **Conclusion:** 27.6% bookings were got cancelled out of all the bookings

# %% [markdown]
# ## Repeated guests

# %%
new_df['is_repeated_guest'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Percentage of repeated guests')
# Out:
# Text(0.5, 1.0, 'Percentage of repeated guests')

# %% [markdown]
# **Conclusion:** Only 3.9% people were revisited the hotels. Rest 96.1% were new guests.

# %% [markdown]
# ## Customer type

# %%
new_df['customer_type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Percentage distribution of Customer Type')
# Out:
# Text(0.5, 1.0, 'Percentage distribution of Customer Type')

# %% [markdown]
# **Conclusion:** Most of the guests were Transient type(82.3%).And transient party were 13.4% and 0.6% belongs to group.Remaining guests belongs to contract type.

# %% [markdown]
# ## Most Preffered Meal Type

# %%
sns.countplot(x= 'meal',data = new_df)
plt.title('Preferred Meal Type')
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations:**
#
# BB(Bed and Breakfast) is the most preffered type of meal by the guests.
#
# Full Board i.e. FB is least preffered.
#
# HB(Half Board) and SC(Self Catering) are equally preffered.

# %% [markdown]
# ## Months and their Bookings

# %%
df00 = new_df.groupby('arrival_date_month')['num_of_bookings'].count().sort_values(ascending = False).reset_index()
df00
# Out:
#    arrival_date_month  num_of_bookings
# 0              August            11232
# 1                July            10024
# 2                 May             8343
# 3               April             7871
# 4                June             7753
# 5               March             7459
# 6             October             6883
# 7           September             6659
# 8            February             6043
# 9            December             5082
# 10           November             4953
# 11            January             4638

# %% [markdown]
# **Conclusion:** As we can see in the table, in July and August most of the bookings happened. It's rainy season. After August, bookings starts declining.

# %% [markdown]
# ## Year and their Bookings

# %%
fig, ax = plt.subplots(figsize= (12,6))
a = sns.countplot(data =new_df, x = 'arrival_date_year',hue = 'hotel')
a.set_title("Bookings Across Different Years")
a.set_xlabel("Year")
a.set_ylabel("Bookings")
plt.show()

# %% [markdown]
# **Conclusion:** Most of the bookings for City Hotel and Resort Hotel were happened in 2016. As we can see most of the bookings were for City Hotels.

# %% [markdown]
# ## ADR across each month

# %%
fig, ax = plt.subplots(figsize= (12,6))
a = sns.lineplot( data = new_df, x= 'arrival_date_month', y = 'adr' ,hue = 'hotel')
a.set_title("ADR Across Each Month")
a.set_ylabel("ADR")
a.set_xlabel('Months')
a.set_xticklabels(a.get_xticklabels(), rotation = 70);
plt.show()
# Out:
# <ipython-input-17-0802661abdb4>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a.set_xticklabels(a.get_xticklabels(), rotation = 70);

# %% [markdown]
# **Conclusion:** Resort hotels had the highest adr in July and August than the city hotels. But in other months adr of Resort hotel was less than the city hotel.
#
# Thus we can say that January, February, March, April, November and December are the good months for customers to get good adr.

# %% [markdown]
# ## Number of Guests from different Countries

# %%
fig, ax = plt.subplots(figsize= (12,6))
a = sns.countplot(x = 'country', data = new_df)
a.set_title('Number of guests from different Countries')
a.set_xlabel('Country')
a.set_ylabel('Number of Guests')
a.set_xticklabels(a.get_xticklabels(), rotation = 90);
plt.xlim([-1,30])
plt.ylim([0,30000])
plt.show()

# %% [markdown]
# **Conclusion:** Most of the guests are from Portugal.

# %% [markdown]
# ## Average ADR of each Hotel

# %%
df1 = new_df.groupby('hotel')['adr'].mean().reset_index()

# %%
a = sns.barplot(data = df1, x = 'hotel' ,y = 'adr')
a.set_title('Average ADR of each Hotel')
a.set_xlabel('Hotel Type')
a.set_ylabel('Average ADR')
# Out:
# Text(0, 0.5, 'Average ADR')

# %% [markdown]
# **Conclusion:** Average ADR for city hotel is high as compared to resort hotels.The city hotels are generating more revenue than the resort hotels.

# %% [markdown]
# ## Average Lead Time for each Hotel

# %%
df2 = new_df.groupby('hotel')['lead_time'].mean().reset_index()

# %%
df2
# Out:
#           hotel  lead_time
# 0    City Hotel  77.689131
# 1  Resort Hotel  84.183939

# %%
a = sns.barplot(data= df2, x = 'hotel', y= 'lead_time')
a.set_title('Average Lead Time for Each Hotel')
a.set_xlabel('Hotel Type')
a.set_ylabel('Average Lead Time')
# Out:
# Text(0, 0.5, 'Average Lead Time')

# %% [markdown]
# **Conclusion:** Average Lead Time for Resort Hotel is high. It means that people plan their trip too early. Usually people prefer Resort Hotel for longer stays. That's why people plan early.

# %% [markdown]
# ## Waiting Time For Each Hotel Type

# %%
df3 = new_df.groupby('hotel')['days_in_waiting_list'].mean().reset_index()

# %%
df3
# Out:
#           hotel  days_in_waiting_list
# 0    City Hotel              1.020424
# 1  Resort Hotel              0.328143

# %%
a = sns.barplot(data = df3, x = 'hotel', y=  'days_in_waiting_list')
a.set_title('Waiting Time For Eah Hotel Type')
a.set_xlabel('Hotel Type')
a.set_ylabel('Average Waiting Time')
# Out:
# Text(0, 0.5, 'Average Waiting Time')

# %% [markdown]
# **Conclusion:** Waiting time period for City Hotels is high as compared to Resort Hotels.That means city hotels are much busier than Resort Hotels.

# %% [markdown]
# ## Most Repeated Guests for Each Hotel

# %%
df4 = new_df.groupby('hotel')['is_repeated_guest'].sum().reset_index()

# %%
a = sns.barplot(data = df4, x = 'hotel', y = 'is_repeated_guest')
a.set_title('Most Repeated Guests for each Hotel')
a.set_xlabel('Hotel Type')
a.set_ylabel('Count of repeated guests')
# Out:
# Text(0, 0.5, 'Count of repeated guests')

# %% [markdown]
# **Conclusion:** Both Hotels has almost same number of repeated guests. In order to get increase the count of repeated guests, hotel management need to take the valueable feedbacks from the guests and try to get good services.

# %% [markdown]
# ## ADR across distribution channel

# %%
df5 = new_df.groupby(['hotel','distribution_channel'])['adr'].mean().reset_index()

# %%
a = sns.barplot(data = df5, x= 'distribution_channel',y= 'adr',hue = 'hotel')
a.set_title('ADR across Distribution Channel')
a.set_xlabel('Distribution Channel')
a.set_ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# **Conclusions:**
#
# 'Direct' and 'TA/TO' has almost equal adr in both type of hotels which is high among the all channels.
#
# 'GDS' has high adr in 'City Hotel' type. GDS needs to increase Resort Hotel bookings. From this we can say that 'Direct' and 'TA/TO' are generating more revenue than the than the other channels.

# %% [markdown]
# ## ADR across Market Segment

# %%
df6 = new_df.groupby(['hotel','market_segment'])['adr'].mean().reset_index()

# %%
a = sns.barplot(data = df6, x = 'market_segment', y = 'adr',hue = 'hotel')
a.set_title('ADR across Market Segment')
a.set_xlabel('Market Segment')
a.set_ylabel('ADR')
a.set_xticklabels(a.get_xticklabels(), rotation = 70);
plt.show()

# %% [markdown]
# **Conclusion:**
#
# Here 'Direct' and 'Online Travel Agency' has high adr for both hotel types. Aviation segment needs to increase Resort Hotel bookings.

# %% [markdown]
# ## Cancellation Rate VS Distribution Channel

# %%
df7 = new_df.groupby(['hotel','distribution_channel'])['is_canceled'].sum().reset_index()
df7
# Out:
#           hotel distribution_channel  is_canceled
# 0    City Hotel            Corporate          330
# 1    City Hotel               Direct          972
# 2    City Hotel                  GDS           36
# 3    City Hotel                TA/TO        14703
# 4  Resort Hotel            Corporate          304
# 5  Resort Hotel               Direct          939
# 6  Resort Hotel                TA/TO         6703
# 7  Resort Hotel            Undefined            0

# %%
a = sns.barplot(data = df7, x = 'distribution_channel',y = 'is_canceled',hue = 'hotel')
a.set_title('Cancellation Rate VS Distribution Channel')
a.set_xlabel('Distribution Channel')
a.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# **Conclusion:** 'TA/TO' distribution channels has the highest cancellations for City Hotels and more than 6000 cancellations for Resort Hotels. In order to reduce the cancellations they should improve their cancellation policies  and deposit policies.

# %% [markdown]
# ## Cancellation Rate VS Market Segment

# %%
df8 = new_df.groupby(['hotel','market_segment'])['is_canceled'].sum().reset_index()
df8
# Out:
#            hotel market_segment  is_canceled
# 0     City Hotel       Aviation           45
# 1     City Hotel  Complementary           55
# 2     City Hotel      Corporate          263
# 3     City Hotel         Direct          911
# 4     City Hotel         Groups          890
# 5     City Hotel  Offline TA/TO         1260
# 6     City Hotel      Online TA        12617
# 7   Resort Hotel  Complementary           31
# 8   Resort Hotel      Corporate          234
# 9   Resort Hotel         Direct          812
# 10  Resort Hotel         Groups          445
# 11  Resort Hotel  Offline TA/TO          797
# 12  Resort Hotel      Online TA         5627

# %%
a = sns.barplot(data = df8, x = 'market_segment', y = 'is_canceled', hue = 'hotel')
a.set_title('Cancellation Rate VS Market Segment')
a.set_xlabel('Market Segment')
a.set_ylabel('Counts')
a.set_xticklabels(a.get_xticklabels(), rotation = 20);
plt.show()

# %% [markdown]
# **Conclusion:** Online TA market segment has highest cancellations for city hotels.

# %% [markdown]
# ## Agents and the counts of booking they made

# %%
new_df['num_of_bookings'] = 1
# Out:
# <ipython-input-51-65b172419f66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['num_of_bookings'] = 1

# %%
df13 = new_df.groupby(['agent','hotel'])['num_of_bookings'].count().sort_values(ascending =False).reset_index()

# %%
df13.head(10)
# Out:
#      agent         hotel  num_of_bookings
# 0      9.0    City Hotel            28752
# 1    240.0  Resort Hotel            12969
# 2  unknown  Resort Hotel             6284
# 3  unknown    City Hotel             5582
# 4     14.0    City Hotel             3347
# 5      7.0    City Hotel             3300
# 6    250.0  Resort Hotel             2763
# 7    241.0  Resort Hotel             1641
# 8     28.0    City Hotel             1502
# 9      1.0    City Hotel             1226

# %%
fig, ax = plt.subplots(figsize= (12,6))
a = sns.barplot(data=  df13, x = 'agent', y = 'num_of_bookings')
a.set_title('Most Bookings Made by Agent')
a.set_xlabel('Agent')
a.set_ylabel('Number of Bookings')
a.set_xticklabels(a.get_xticklabels(), rotation = 20);
plt.xlim([-1,20])
plt.ylim([0,30000])
plt.show()

# %% [markdown]
# **Conclusion:** Agent Id no - 9 made the highest bookings which is more than 28750.

# %% [markdown]
# ## Co-relation of the columns

# %%
new_df.corr()
# Out:
# <ipython-input-56-326e7bbec5b0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_df.corr()
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.183730           0.087665
# lead_time                          0.183730   1.000000           0.138786
# arrival_date_year                  0.087665   0.138786           1.000000
# arrival_date_week_number           0.000864   0.100970          -0.514123
# arrival_date_day_of_month          0.005281   0.009865          -0.010282
# stays_in_weekend_nights            0.059599   0.233679           0.005000
# stays_in_week_nights               0.082818   0.309916           0.003930
# adults                             0.080295   0.137500           0.037455
# ...

# %%
fig, ax = plt.subplots(figsize= (15,8))
a = sns.heatmap(data = new_df.corr(), annot = True, cmap = "coolwarm")
a.set_title('Co-relation of the columns')
# Out:
# <ipython-input-57-409caffb4b9c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a = sns.heatmap(data = new_df.corr(), annot = True, cmap = "coolwarm")
# Text(0.5, 1.0, 'Co-relation of the columns')
